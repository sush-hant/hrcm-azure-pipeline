# %%
# %sql
CREATE SCHEMA IF NOT EXISTS gold

# %%
# %sql
CREATE TABLE IF NOT EXISTS gold.dim_provider(
  provider_id STRING,
  first_name STRING,
  last_name  STRING,
  dept_id STRING,
  NPI LONG,
  datasource STRING
)

# %%
# %sql
TRUNCATE TABLE gold.dim_provider

# %%
# %sql
INSERT INTO gold.dim_provider
SELECT
providerid,
firstname,
lastname,
concat(deptid,'-',datasource) dept_id,
npi,
datasource
FROM silver.providers
WHERE is_qurantined = false

# %%
# %sql
SELECT * FROM gold.dim_provider LIMIT 10
